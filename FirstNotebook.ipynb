# %%
print("Hello, Colab!")
# Out:
# Hello, Colab!

# %%
# Different data types
a = 10
b = 20.5
c = "Python"
d = True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# Arithmetic Operators
x = 10
y = 5
print(x + y)
print(x - y)
print(x * y)
print(x / y)
# Out:
# 15
# 5
# 50
# 2.0
